# %% [markdown]
# # SoReMo Illinois Interactive Map (Folium)
#
# This notebook builds the first version of the Illinois data center map.
#
# Layers:
# - Existing
# - Proposed / Under Dev
# - Denied (Naperville)
# - Clusters
#
# Outputs:
# - Interactive HTML map saved to `outputs/maps/illinois_datacenters_map.html`

# %%
# Imports + path setup
import os
import sys
from pathlib import Path
import pandas as pd

# Allow imports from src/ when running notebook
REPO_ROOT = Path.cwd().parents[0]  # notebooks/ -> repo root
sys.path.append(str(REPO_ROOT))

from src.config import IL_SITES_CSV, DEFAULT_OUTPUT_MAP
from src.utils.io import read_csv, ensure_parent_dir
from src.mapping.build_map import build_illinois_map

REPO_ROOT, IL_SITES_CSV, DEFAULT_OUTPUT_MAP
# Out:
# (WindowsPath('c:/Users/Owner/Downloads/SoReMo-S26-people-v-hasty-ai'),
#  WindowsPath('C:/Users/Owner/Downloads/SoReMo-S26-people-v-hasty-ai/data/processed/il_sites.csv'),
#  WindowsPath('C:/Users/Owner/Downloads/SoReMo-S26-people-v-hasty-ai/outputs/maps/illinois_datacenters_map.html'))

# %%
# Load data
sites = read_csv(IL_SITES_CSV)
sites.head()
# Out:
#     site_id                                 name     layer  \
# 0  IL-EX-01              Meta DeKalb Data Center  existing
# 1  IL-EX-02       Stream Data Centers Chicago II  existing
# 2  IL-EX-03        Stream Data Centers Chicago I  existing
# 3  IL-EX-04                          Equinix CH3  existing
# 4  IL-EX-05  Digital Realty ORD10 (350 E Cermak)  existing
#
#               operator                               city state  \
# 0                 Meta                             DeKalb    IL
# 1  Stream Data Centers                  Elk Grove Village    IL
# 2  Stream Data Centers                  Elk Grove Village    IL
# 3              Equinix  Elk Grove Village (Chicago metro)    IL
# 4       Digital Realty                            Chicago    IL
#
#                                address_or_hint     lat    lon  \
# 0                        Gurler Rd, DeKalb, IL  41.884 -88.75
# 1    Elk Grove Village, IL (Stream Chicago II)  42.000 -87.97
# 2     Elk Grove Village, IL (Stream Chicago I)  42.000 -87.97
# 3  Elk Grove area, Chicago metro (Equinix CH3)  42.000 -87.97
# 4           350 E Cermak Rd, Chicago, IL 60616  41.853 -87.62
#
#   location_precision                              surroundings_snapshot  \
# 0             approx  South edge of DeKalb near major arterials and ...
# 1             approx  Elk Grove positioned as a data center and conn...
# 2             approx       Same regional cluster dynamics as Chicago II
# 3             approx          Part of the Elk Grove data center cluster
# 4              exact  South Loop dense urban corridor; historic indu...
#
#                                    community_signals  \
# 0  Expansion framed as jobs + investment by City ...
# 1      Partnerships and utility readiness emphasized
# 2  Public framing focuses on infrastructure readi...
# 3  Appears in industry operations context, not co...
# 4  Emphasis on interconnection ecosystem and mode...
#
#                                            stressors  \
# 0  Substation or grid upgrades, water use, backup...
# 1  Grid capacity expansions, generator/mechanical...
# 2  Cumulative impacts across nearby sites, grid u...
# 3  Grid and redundancy infrastructure, generator ...
# 4  Generator testing and emissions, rooftop mecha...
#
#                                              sources
# 0  https://www.cityofdekalb.com/CivicAlerts.aspx?...
# 1  https://www.streamdatacenters.com/locations/ch...
# 2  https://www.streamdatacenters.com/news/stream-...
# 3  https://www.datacenterdynamics.com/en/news/cbo...
# 4  https://www.digitalrealty.com/data-centers/ame...

# %%
# Validate schema
required_cols = [
    "site_id",
    "name",
    "layer",  # existing / proposed / denied
    "operator",
    "city",
    "state",
    "address_or_hint",
    "lat",
    "lon",
    "location_precision",
    "surroundings_snapshot",
    "community_signals",
    "stressors",
    "sources"
]

missing = [c for c in required_cols if c not in sites.columns]
if missing:
    raise ValueError(f"Missing required columns: {missing}")

print("Schema looks good.")
print("Row count:", len(sites))
print(sites["layer"].value_counts(dropna=False))
# Out:
# Schema looks good.
# Row count: 15
# layer
# existing    7
# proposed    7
# denied      1
# Name: count, dtype: int64

# %%
# Check which rows are missing coordinates (expected for v1)
missing_coords = sites[sites[["lat", "lon"]].isna().any(axis=1)]
print("Sites missing lat/lon:", len(missing_coords))
missing_coords[["site_id", "name", "city", "address_or_hint", "location_precision"]]
# Out:
# Sites missing lat/lon: 0
# Empty DataFrame
# Columns: [site_id, name, city, address_or_hint, location_precision]
# Index: []

# %%
# Build map (default Illinois view)
m = build_illinois_map(sites)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b645421afd0da03fe1da64b0490844be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b645421afd0da03fe1da64b0490844be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b645421afd0da03fe1da64b0490844be = L.map(
#                 &quot;map_b645421afd0da03fe1da64b0490844be&quot;,
#                 {
#                     center: [40.0, -89.2],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75f9300e7c75672f7c7b2d3e9a88dffb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_75f9300e7c75672f7c7b2d3e9a88dffb.addTo(map_b645421afd0da03fe1da64b0490844be);
#
#
#             var feature_group_4cfb188c7da7e8f96a9001adaaaed67a = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_61498eefdf38feca3c4ceb5fefb54af8 = L.circle(
#                 [42.0, -87.97],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_4cfb188c7da7e8f96a9001adaaaed67a);
#
#
#         var popup_6a3ca477d6927188fff03fb46fc5a2ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_206dffa75be43a01deaf394d9ccb7b4f = $(`&lt;div id=&quot;html_206dffa75be43a01deaf394d9ccb7b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elk Grove Village cluster (multiple existing + proposed sites)&lt;/div&gt;`)[0];
#                 popup_6a3ca477d6927188fff03fb46fc5a2ea.setContent(html_206dffa75be43a01deaf394d9ccb7b4f);
#
#
#
#         circle_61498eefdf38feca3c4ceb5fefb54af8.bindPopup(popup_6a3ca477d6927188fff03fb46fc5a2ea)
#         ;
#
#
#
#
#             var circle_dd860f121a25156a3888c09bba96173f = L.circle(
#                 [41.864, -87.631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_4cfb188c7da7e8f96a9001adaaaed67a);
#
#
#         var popup_5939cca3dc88ae21618ff83b2231312f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_088aa55bbc9a08d74978c2e730bc3403 = $(`&lt;div id=&quot;html_088aa55bbc9a08d74978c2e730bc3403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago core cluster (interconnection hubs and dense urban facilities)&lt;/div&gt;`)[0];
#                 popup_5939cca3dc88ae21618ff83b2231312f.setContent(html_088aa55bbc9a08d74978c2e730bc3403);
#
#
#
#         circle_dd860f121a25156a3888c09bba96173f.bindPopup(popup_5939cca3dc88ae21618ff83b2231312f)
#         ;
#
#
#
#
#             var circle_9afbba4520bd1100be3e8edbdd6422be = L.circle(
#                 [41.865, -88.751],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_4cfb188c7da7e8f96a9001adaaaed67a);
#
#
#         var popup_8653d555d6d1c30b06f84e846d6400eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58f6bdc0a11086db5187fc894bb86c57 = $(`&lt;div id=&quot;html_58f6bdc0a11086db5187fc894bb86c57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DeKalb area cluster (campus expansion + approved proposal corridor)&lt;/div&gt;`)[0];
#                 popup_8653d555d6d1c30b06f84e846d6400eb.setContent(html_58f6bdc0a11086db5187fc894bb86c57);
#
#
#
#         circle_9afbba4520bd1100be3e8edbdd6422be.bindPopup(popup_8653d555d6d1c30b06f84e846d6400eb)
#         ;
#
#
#
#
#             feature_group_4cfb188c7da7e8f96a9001adaaaed67a.addTo(map_b6

# %%
# Export HTML map
ensure_parent_dir(DEFAULT_OUTPUT_MAP)
m.save(str(DEFAULT_OUTPUT_MAP))
print("Saved:", DEFAULT_OUTPUT_MAP)
# Out:
# Saved: C:\Users\Owner\Downloads\SoReMo-S26-people-v-hasty-ai\outputs\maps\illinois_datacenters_map.html

# %%
# zoom preset maps
presets = {
    "Chicago core": {"center": [41.864, -87.631], "zoom": 12},
    "Elk Grove cluster": {"center": [42.000, -87.970], "zoom": 12},
    "DeKalb cluster": {"center": [41.865, -88.751], "zoom": 12},
    "Naperville denied": {"center": [41.812, -88.170], "zoom": 13},
}

preset_name = "Elk Grove cluster"
p = presets[preset_name]

m2 = build_illinois_map(sites, center=p["center"], zoom_start=p["zoom"])
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be06b5eb9918affdecb99e2c414755fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be06b5eb9918affdecb99e2c414755fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be06b5eb9918affdecb99e2c414755fa = L.map(
#                 &quot;map_be06b5eb9918affdecb99e2c414755fa&quot;,
#                 {
#                     center: [42.0, -87.97],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3f4bd1907cd0d00ece0de61be8549d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d3f4bd1907cd0d00ece0de61be8549d0.addTo(map_be06b5eb9918affdecb99e2c414755fa);
#
#
#             var feature_group_6773d04967e0a3a66df21dd906054adb = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_2e8f0ea72720c513a0213b7bd53439c2 = L.circle(
#                 [42.0, -87.97],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_6773d04967e0a3a66df21dd906054adb);
#
#
#         var popup_08d7487b2813aa5c1501e7f8e005a3d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1530f48aa1e0e231afc796e3496eed4f = $(`&lt;div id=&quot;html_1530f48aa1e0e231afc796e3496eed4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elk Grove Village cluster (multiple existing + proposed sites)&lt;/div&gt;`)[0];
#                 popup_08d7487b2813aa5c1501e7f8e005a3d6.setContent(html_1530f48aa1e0e231afc796e3496eed4f);
#
#
#
#         circle_2e8f0ea72720c513a0213b7bd53439c2.bindPopup(popup_08d7487b2813aa5c1501e7f8e005a3d6)
#         ;
#
#
#
#
#             var circle_b21e37a5b96d37486a0727fc7b3ea702 = L.circle(
#                 [41.864, -87.631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_6773d04967e0a3a66df21dd906054adb);
#
#
#         var popup_6122b76bb689be752d1b08e05b7dac1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4e6d91214957d7f50170d3d9b33f835 = $(`&lt;div id=&quot;html_b4e6d91214957d7f50170d3d9b33f835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago core cluster (interconnection hubs and dense urban facilities)&lt;/div&gt;`)[0];
#                 popup_6122b76bb689be752d1b08e05b7dac1a.setContent(html_b4e6d91214957d7f50170d3d9b33f835);
#
#
#
#         circle_b21e37a5b96d37486a0727fc7b3ea702.bindPopup(popup_6122b76bb689be752d1b08e05b7dac1a)
#         ;
#
#
#
#
#             var circle_43126b8ea861e66e4f504e127b2bf830 = L.circle(
#                 [41.865, -88.751],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: &quot;6,10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_6773d04967e0a3a66df21dd906054adb);
#
#
#         var popup_5c5ebca290e0569ab869130fc1155d6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba4c6c09c55ad65a0fcf1eb2773b011b = $(`&lt;div id=&quot;html_ba4c6c09c55ad65a0fcf1eb2773b011b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DeKalb area cluster (campus expansion + approved proposal corridor)&lt;/div&gt;`)[0];
#                 popup_5c5ebca290e0569ab869130fc1155d6a.setContent(html_ba4c6c09c55ad65a0fcf1eb2773b011b);
#
#
#
#         circle_43126b8ea861e66e4f504e127b2bf830.bindPopup(popup_5c5ebca290e0569ab869130fc1155d6a)
#         ;
#
#
#
#
#             feature_group_6773d04967e0a3a66df21dd906054adb.addTo(map_

# %%
summary = (
    sites.groupby(["layer", "city"], dropna=False)
    .size()
    .reset_index(name="count")
    .sort_values(["layer", "count"], ascending=[True, False])
)
summary
# Out:
#        layer                               city  count
# 0     denied                         Naperville      1
# 1   existing                            Chicago      3
# 3   existing                  Elk Grove Village      2
# 2   existing                             DeKalb      1
# 4   existing  Elk Grove Village (Chicago metro)      1
# 6   proposed                  Elk Grove Village      2
# 5   proposed                        DeKalb area      1
# 7   proposed                    Hoffman Estates      1
# 8   proposed                       Minooka area      1
# 9   proposed                Mount Prospect area      1
# 10  proposed                Talkington Township      1

# %%
summary_path = REPO_ROOT / "outputs" / "figures" / "il_site_counts_by_layer_city.csv"
summary_path.parent.mkdir(parents=True, exist_ok=True)
summary.to_csv(summary_path, index=False)
summary_path
# Out:
# WindowsPath('c:/Users/Owner/Downloads/SoReMo-S26-people-v-hasty-ai/outputs/figures/il_site_counts_by_layer_city.csv')
